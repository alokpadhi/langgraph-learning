# %% [markdown]
# ### simple mcp server

# %%
from mcp.server import Server
from mcp.server.stdio import stdio_server
from mcp.types import Tool, TextContent
import asyncio

# %%
# create a mcp server
app = Server("demo-server")

# %%
# define a tool
@app.list_tools()
async def list_tools() -> list[Tool]:
    """List available tools"""
    return [
        Tool(
            name="get_weather",
            description="Get current weather for a city",
            inputSchema={
                "type": "object",
                "properties": {
                    "city": {
                        "type": "string",
                        "description": "City name"
                    }
                },
                "required": ["city"]
            }
        )
    ]

# %%
@app.call_tool()
async def call_tool(name: str, arguments: dict) -> list[TextContent]:
    """Handle tool calls"""
    
    if name == "get_weather":
        city = arguments.get("city", "")
        
        # Simulated weather data
        weather_data = {
            "paris": "18°C, Partly cloudy",
            "tokyo": "22°C, Sunny",
            "new york": "15°C, Rainy"
        }
        
        result = weather_data.get(city.lower(), f"Weather data not available for {city}")
        
        return [TextContent(
            type="text",
            text=result
        )]
    
    return [TextContent(type="text", text=f"Unknown tool: {name}")]

# %%
async def main():
    async with stdio_server() as (read_stream, write_stream):
        await app.run(
            read_stream,
            write_stream,
            app.create_initialization_options()
        )

# %%
await main()
# Out:
# /home/alokpadhi/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/ast.py:276: RuntimeWarning: coroutine 'main' was never awaited
#   for item in field:
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 await main()
#
# Cell In[5], line 2, in main()
#       1 async def main():
# ----> 2     async with stdio_server() as (read_stream, write_stream):
#       3         await app.run(
#       4             read_stream,
#       5             write_stream,
#       6             app.create_initialization_options()
#       7         )
#
# File ~/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/contextlib.py:210, in _AsyncGeneratorContextManager.__aenter__(self)
#     208 del self.args, self.kwds, self.func
#     209 try:
# --> 210     return await anext(self.gen)
#     211 except StopAsyncIteration:
#     212     raise RuntimeError("generator didn't yield") from None
#
# File ~/langgraph-learning/.venv/lib/python3.11/site-packages/mcp/server/stdio.py:49, in stdio_server(stdin, stdout)
#      47     stdin = anyio.wrap_file(TextIOWrapper(sys.stdin.buffer, encoding="utf-8"))
#      48 if not stdout:
# ---> 49     stdout = anyio.wrap_file(TextIOWrapper(sys.stdout.buffer, encoding="utf-8"))
#      51 read_stream: MemoryObjectReceiveStream[SessionMessage | Exception]
#      52 read_stream_writer: MemoryObjectSendStream[SessionMessage | Exception]
#
# AttributeError: 'OutStream' object has no attribute 'buffer'
